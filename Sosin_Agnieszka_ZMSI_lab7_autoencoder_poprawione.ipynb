# %% [markdown]
# <a href="https://colab.research.google.com/github/agsosin/COLAB/blob/main/Sosin_Agnieszka_ZMSI_lab7_autoencoder_poprawione.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
#     <font size="5"> Zaawansowane Metody Uczenia Maszynowego i Głębokiego<br/>
#         <small><em>Studia stacjonarne II stopnia 2024/2025</em><br/>Kierunek: Informatyka<br>Specjalność: Systemy inteligentne i rozszerzona rzeczywistość</small>
#     </font>
# </center>
# <br>

# %% [markdown]
# # Laboratorium nr 10: Autoencoders

# %% [markdown]
# ## Montowanie Google Drive

# %% [markdown]
# ## Import bibliotek

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
print('Numpy version:', np.__version__)
print('Tensorflow version:', tf.__version__)
# Out:
# Numpy version: 1.26.4
# Tensorflow version: 2.18.0

# %% [markdown]
# ## Baza MNIST
#
# - Baza MNIST zawiera zbiór trenujący składający się z 60,000 przykładów skanów ręcznie pisanych cyfr od 0 do 9 (problem klasyfikacyjny z 10 klasami).
# - Zbiór testowy zawiera 10,000 przykładów.
# - Każdy obraz ma rozmiar 28x28 pikseli. Stanowią one 28 * 28 = 784 wejść do sieci.
#
# #### Pobieranie bazy MNIST
# - Bazę MNIST można pobrać bespośrednio ze strony http://yann.lecun.com/exdb/mnist/
# - Najwygodniej jednak jest użyć bazy MNIST z wykorzystaniem biblioteki Keras

# %%
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data()
print(train_images.shape, train_labels.shape, test_images.shape, test_labels.shape)
train_images = np.expand_dims(train_images, axis=-1)/255.
train_labels = np.int64(train_labels)
test_images = np.expand_dims(test_images, axis=-1)/255.
test_labels = np.int64(test_labels)
print(train_images.shape, train_labels.shape, test_images.shape, test_labels.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# (60000, 28, 28) (60000,) (10000, 28, 28) (10000,)
# (60000, 28, 28, 1) (60000,) (10000, 28, 28, 1) (10000,)

# %% [markdown]
# Przykładowe cyfry:

# %%
plt.figure(figsize=(10,10))
random_inds = np.random.choice(60000, 36)
for i in range(36):
    plt.subplot(6,6,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    image_ind = random_inds[i]
    plt.imshow(np.squeeze(train_images[image_ind]), cmap=plt.cm.binary)
    plt.xlabel(train_labels[image_ind])

# %% [markdown]
# ## AutoEncoder
# Stwórz model AutoEncodera. Użyj warst Dense. Wytrenuj i zwizualizuj odtworzone cyfry.

# %%
from tensorflow.keras.layers import Input, Dense, Flatten, Reshape, Conv2D, Conv2DTranspose
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt
import numpy as np

# Funkcja enkodera
def encoder_with_label(latent_dim, num_classes):
    # Wejście obrazu 28x28x1
    input_img = Input(shape=(28, 28, 1))
    x = Conv2D(32, (3, 3), activation='relu', padding='same')(input_img)
    x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = Flatten()(x)
    # Warstwa latentna
    latent = Dense(latent_dim, activation='relu')(x)
    # Wyjście klasyfikatora
    label_output = Dense(num_classes, activation='softmax', name="LabelOutput")(latent)
    return Model(inputs=input_img, outputs=[latent, label_output], name="EncoderWithLabel")

# Funkcja dekodera
def decoder(latent_dim):
    latent_input = Input(shape=(latent_dim,))
    x = Dense(7 * 7 * 64, activation='relu')(latent_input)
    x = Reshape((7, 7, 64))(x)
    x = Conv2DTranspose(64, (3, 3), activation='relu', strides=(2, 2), padding='same')(x) # Upsampling to 14x14
    x = Conv2DTranspose(32, (3, 3), activation='relu', strides=(2, 2), padding='same')(x) # Upsampling to 28x28
    decoded = Conv2DTranspose(1, (3, 3), activation='sigmoid', padding='same', name="ReconstructionOutput")(x)
    return Model(inputs=latent_input, outputs=decoded, name="Decoder")

# Ładowanie danych MNIST
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0
x_train = np.expand_dims(x_train, axis=-1)  # Dodanie kanału
x_test = np.expand_dims(x_test, axis=-1)

# Parametry
latent_dim = 16
num_classes = 10

# Tworzenie modeli
enc = encoder_with_label(latent_dim, num_classes)
dec = decoder(latent_dim)

# Połączenie modeli w pełny autoenkoder
input_img = Input(shape=(28, 28, 1))
latent, label_output = enc(input_img)
reconstructed = dec(latent)
autoencoder = Model(inputs=input_img, outputs=[reconstructed, label_output], name="AutoencoderWithLabel")

# Kompilacja modelu
autoencoder.compile(
    optimizer='adam',
    loss=['mse', 'sparse_categorical_crossentropy'],  # Rekonstrukcja + Klasyfikacja
    metrics=[None, 'accuracy']  # Rekonstrukcja bez metryki, klasyfikacja z accuracy
    #OR
    metrics={'ReconstructionOutput': None, 'LabelOutput': 'accuracy'} #Using output layer names
)

# Kompilacja modelu
autoencoder.compile(
    optimizer='adam',
    loss=['mse', 'sparse_categorical_crossentropy'],  # Rekonstrukcja + Klasyfikacja
    # Use output layer names in metrics for clarity
    metrics=[None, 'accuracy']  #Instead of using dictionary-like metrics
)

# Train the model and store the training history
history = autoencoder.fit(
    x_train, [x_train, y_train],  # Input data and corresponding labels
    epochs=30,                  # Number of training epochs
    batch_size=128,             # Batch size for training
    validation_split=0.1        # Fraction of data used for validation
)
# Out:
# Epoch 1/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 20s 27ms/step - Decoder_loss: 0.0758 - EncoderWithLabel_accuracy: 0.8269 - EncoderWithLabel_loss: 0.5407 - loss: 0.6165 - val_Decoder_loss: 0.0318 - val_EncoderWithLabel_accuracy: 0.9777 - val_EncoderWithLabel_loss: 0.0780 - val_loss: 0.1095
# Epoch 2/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - Decoder_loss: 0.0303 - EncoderWithLabel_accuracy: 0.9794 - EncoderWithLabel_loss: 0.0700 - loss: 0.1002 - val_Decoder_loss: 0.0263 - val_EncoderWithLabel_accuracy: 0.9827 - val_EncoderWithLabel_loss: 0.0586 - val_loss: 0.0846
# Epoch 3/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - Decoder_loss: 0.0262 - EncoderWithLabel_accuracy: 0.9871 - EncoderWithLabel_loss: 0.0428 - loss: 0.0690 - val_Decoder_loss: 0.0242 - val_EncoderWithLabel_accuracy: 0.9840 - val_EncoderWithLabel_loss: 0.0573 - val_loss: 0.0812
# Epoch 4/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - Decoder_loss: 0.0244 - EncoderWithLabel_accuracy: 0.9915 - EncoderWithLabel_loss: 0.0273 - loss: 0.0516 - val_Decoder_loss: 0.0235 - val_EncoderWithLabel_accuracy: 0.9867 - val_EncoderWithLabel_loss: 0.0491 - val_loss: 0.0722
# Epoch 5/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - Decoder_loss: 0.0232 - EncoderWithLabel_accuracy: 0.9937 - EncoderWithLabel_loss: 0.0206 - loss: 0.0439 - val_Decoder_loss: 0.0228 - val_EncoderWithLabel_accuracy: 0.9873 - val_EncoderWithLabel_loss: 0.0491 - val_loss: 0.0716
# Epoch 6/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - Decoder_loss: 0.0224 - EncoderWithLabel_accuracy: 0.9953 - EncoderWithLabel_loss: 0.0140 - loss: 0.0364 - val_Decoder_loss: 0.0227 - val_EncoderWithLabel_accuracy: 0.9863 - val_EncoderWithLabel_loss: 0.0530 - val_loss: 0.0751
# Epoch 7/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - Decoder_loss: 0.0221 - EncoderWithLabel_accuracy: 0.9957 - EncoderWithLabel_loss: 0.0126 - loss: 0.0346 - val_Decoder_loss: 0.0217 - val_EncoderWithLabel_accuracy: 0.9853 - val_EncoderWithLabel_loss: 0.0599 - val_loss: 0.0811
# Epoch 8/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - Decoder_loss: 0.0215 - EncoderWithLabel_accuracy: 0.9965 - EncoderWithLabel_loss: 0.0108 - loss: 0.0323 - val_Decoder_loss: 0.0210 - val_EncoderWithLabel_accuracy: 0.9878 - val_EncoderWithLabel_loss: 0.0584 - val_loss: 0.0788
# Epoch 9/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - Decoder_loss: 0.0206 - EncoderWithLabel_accuracy: 0.9980 - EncoderWithLabel_loss: 0.0068 - loss: 0.0274 - val_Decoder_loss: 0.0206 - val_EncoderWithLabel_accuracy: 0.9863 - val_EncoderWithLabel_loss: 0.0601 - val_loss: 0.0801
# Epoch 10/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - Decoder_loss: 0.0202 - EncoderWithLabel_accuracy: 0.9985 - EncoderWithLabel_loss: 0.0055 - loss: 0.0257 - val_Decoder_loss: 0.0201 - val_EncoderWithLabel_accuracy: 0.9867 - val_EncoderWithLabel_loss: 0.0737 - val_loss: 0.0930
# Epoch 11/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - Decoder_loss: 0.0199 - EncoderWithLabel_accuracy: 0.9977 - EncoderWithLabel_loss: 0.0076 - loss: 0.0275 - val_Decoder_loss: 0.0197 - val_EncoderWithLabel_accuracy: 0.9865 - val_EncoderWithLabel_loss: 0.0687 - val_loss: 0.0878
# Epoch 12/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - Decoder_loss: 0.0195 - EncoderWithLabel_accuracy: 0.9983 - EncoderWithLabel_loss: 0.0049 - loss: 0.0244 - val_Decoder_loss: 0.0200 - val_EncoderWithLabel_accuracy: 0.9862 - val_EncoderWithLabel_loss: 0.0739 - val_loss: 0.0934
# Epoch 13/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - Decoder_loss: 0.0201 - EncoderWithLabel_accuracy: 0.9971 - EncoderWithLabel_loss: 0.0086 - loss: 0.0287 - val_Decoder_loss: 0.0196 - val_EncoderWithLabel_accuracy: 0.9857 - val_EncoderWithLabel_loss: 0.0837 - val_loss: 0.1028
# Epoch 14/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - Decoder_loss: 0.0191 - EncoderWithLabel_accuracy: 0.9990 - EncoderWithLabel_loss: 0.0037 - loss: 0.0228 - val_Decoder_loss: 0.0188 - val_EncoderWithLabel_accuracy: 0.9873 - val_EncoderWithLabel_loss: 0.0719 - val_loss: 0.0900
# Epoch 15/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - Decoder_loss: 0.0188 - EncoderWithLabel_accuracy: 0.9984 - EncoderWithLabel_loss: 0.0042 - loss: 0.0231 - val_Decoder_loss: 0.0186 - val_EncoderWithLabel_accuracy: 0.9878 - val_EncoderWithLabel_loss: 0.0774 - val_loss: 0.0953
# Epoch 16/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - Decoder_loss: 0.0188 - EncoderWithLabel_accuracy: 0.9984 - EncoderWithLabel_loss: 0.0062 - loss: 0.0250 - val_Decoder_loss: 0.0184 - val_EncoderWithLabel_accuracy: 0.9860 - val_EncoderWithLabel_loss: 0.0779 - val_loss: 0.0957
# Epoch 17/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - Decoder_loss: 0.0184 - EncoderWithLabel_accuracy: 0.9985 - EncoderWithLabel_loss: 0.0048 - loss: 0.0232 - val_Decoder_loss: 0.0184 - val_EncoderWithLabel_accuracy: 0.9853 - val_EncoderWithLabel_loss: 0.0909 - val_loss: 0.1085
# Epoch 18/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - Decoder_loss: 0.0178 - EncoderWithLabel_accuracy: 0.9991 - EncoderWithLabel_loss: 0.0028 - loss: 0.0206 - val_Decoder_loss: 0.0180 - val_EncoderWithLabel_accuracy: 0.9865 - val_EncoderWithLabel_loss: 0.0780 - val_loss: 0.0953
# Epoch 19/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - Decoder_loss: 0.0179 - EncoderWithLabel_accuracy: 0.9984 - EncoderWithLabel_loss: 0.0040 - loss: 0.0219 - val_Decoder_loss: 0.0176 - val_EncoderWithLabel_accuracy: 0.9887 - val_EncoderWithLabel_loss: 0.0786 - val_loss: 0.0954
# Epoch 20/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - Decoder_loss: 0.0173 - EncoderWithLabel_accuracy: 0.9994 - EncoderWithLabel_loss: 0.0022 - loss: 0.0195 - val_Decoder_loss: 0.0171 - val_EncoderWithLabel_accuracy: 0.9863 - val_EncoderWithLabel_loss: 0.0920 - val_loss: 0.1083
# Epoch 21/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - Decoder_loss: 0.0164 - EncoderWithLabel_accuracy: 0.9998 - EncoderWithLabel_loss: 8.0633e-04 - loss: 0.0172 - val_Decoder_loss: 0.0180 - val_EncoderWithLabel_accuracy: 0.9852 - val_EncoderWithLabel_loss: 0.0984 - val_loss: 0.1156
# Epoch 22/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - Decoder_loss: 0.0168 - EncoderWithLabel_accuracy: 0.9993 - EncoderWithLabel_loss: 0.0025 - loss: 0.0193 - val_Decoder_loss: 0.0174 - val_EncoderWithLabel_accuracy: 0.9850 - val_EncoderWithLabel_loss: 0.0960 - val_loss: 0.1128
# Epoch 23/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - Decoder_loss: 0.0174 - EncoderWithLabel_accuracy: 0.9982 - EncoderWithLabel_loss: 0.0059 - loss: 0.0232 - val_Decoder_loss: 0.0181 - val_EncoderWithLabel_accuracy: 0.9858 - val_EncoderWithLabel_loss: 0.0840 - val_loss: 0.1015
# Epoch 24/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - Decoder_loss: 0.0172 - EncoderWithLabel_accuracy: 0.9988 - EncoderWithLabel_loss: 0.0037 - loss: 0.0209 - val_Decoder_loss: 0.0173 - val_EncoderWithLabel_accuracy: 0.9853 - val_EncoderWithLabel_loss: 0.0982 - val_loss: 0.1147
# Epoch 25/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - Decoder_loss: 0.0164 - EncoderWithLabel_accuracy: 0.9995 - EncoderWithLabel_loss: 0.0018 - loss: 0.0183 - val_Decoder_loss: 0.0175 - val_EncoderWithLabel_accuracy: 0.9847 - val_EncoderWithLabel_loss: 0.0916 - val_loss: 0.1084
# Epoch 26/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - Decoder_loss: 0.0167 - EncoderWithLabel_accuracy: 0.9989 - EncoderWithLabel_loss: 0.0027 - loss: 0.0194 - val_Decoder_loss: 0.0168 - val_EncoderWithLabel_accuracy: 0.9883 - val_EncoderWithLabel_loss: 0.0865 - val_loss: 0.1025
# Epoch 27/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 11s 13ms/step - Decoder_loss: 0.0163 - EncoderWithLabel_accuracy: 0.9992 - EncoderWithLabel_loss: 0.0026 - loss: 0.0189 - val_Decoder_loss: 0.0164 - val_EncoderWithLabel_accuracy: 0.9867 - val_EncoderWithLabel_loss: 0.0885 - val_loss: 0.1042
# Epoch 28/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - Decoder_loss: 0.0159 - EncoderWithLabel_accuracy: 0.9994 - EncoderWithLabel_loss: 0.0018 - loss: 0.0177 - val_Decoder_loss: 0.0159 - val_EncoderWithLabel_accuracy: 0.9882 - val_EncoderWithLabel_loss: 0.0925 - val_loss: 0.1075
# Epoch 29/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - Decoder_loss: 0.0156 - EncoderWithLabel_accuracy: 0.9994 - EncoderWithLabel_loss: 0.0026 - loss: 0.0182 - val_Decoder_loss: 0.0162 - val_EncoderWithLabel_accuracy: 0.9863 - val_EncoderWithLabel_loss: 0.1050 - val_loss: 0.1206
# Epoch 30/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - Decoder_loss: 0.0155 - EncoderWithLabel_accuracy: 0.9996 - EncoderWithLabel_loss: 0.0014 - loss: 0.0170 - val_Decoder_loss: 0.0157 - val_EncoderWithLabel_accuracy: 0.9880 - val_EncoderWithLabel_loss: 0.1091 - val_loss: 0.1239
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-bacaf61f023b> in <cell line: 0>()
#      78 plt.plot(history.history['loss'], label='Całkowita strata')
#      79 #plt.plot(history.history['ReconstructionOutput_loss'], label='Strata rekonstrukcji')
# ---> 80 plt.plot(history.history['LabelOutput_loss'], label='Strata klasyfikacji')
#      81 plt.legend()
#      82 plt.title("Straty podczas trenowania")
#
# KeyError: 'LabelOutput_loss'

# %%
# Wizualizacja strat
plt.plot(history.history['loss'], label='Całkowita strata')
#plt.plot(history.history['ReconstructionOutput_loss'], label='Strata rekonstrukcji')
#plt.plot(history.history['LabelOutput_loss'], label='Strata klasyfikacji')
plt.legend()
plt.title("Straty podczas trenowania")
plt.show()

# Wizualizacja odtworzonych obrazów
n = 10
reconstructed, predicted_labels = autoencoder.predict(x_test[:n])

plt.figure(figsize=(20, 4))
for i in range(n):
    # Oryginalny obraz
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].squeeze(), cmap='gray')
    plt.title(f"Label: {y_test[i]}")
    plt.axis('off')

    # Odtworzony obraz
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(reconstructed[i].squeeze(), cmap='gray')
    plt.title(f"Pred: {np.argmax(predicted_labels[i])}")
    plt.axis('off')

plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 865ms/step

# %%
# model autoencodera i trenowanie
n = 9 # sprawdz działanie dla różnych wielkości przestrzeni latentnej
# enc = encoder(n) # Original line causing the error
enc = encoder_with_label(n, num_classes=10) # Use the correct function name and pass num_classes
dec = decoder(n)
# Instead of using Sequential, create a Functional model
input_img = Input(shape=(28, 28, 1))
latent, _ = enc(input_img)  # Get the latent representation, ignore the label output
reconstructed = dec(latent)  # Pass the latent representation to the decoder
ae_model = Model(inputs=input_img, outputs=reconstructed) # Create the autoencoder model

ae_model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_8 (InputLayer)           │ (None, 28, 28, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ EncoderWithLabel (Functional)        │ [(None, 9), (None, 10)]     │         470,509 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Decoder (Functional)                 │ (None, 28, 28, 1)           │          87,041 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 557,550 (2.13 MB)
#  Trainable params: 557,550 (2.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
ae_model.compile(optimizer='adam', loss='mse')
ae_model.fit(train_images, train_images, epochs=30, batch_size=128, validation_split=0.1)

# uczenie z klasyfikatorem
#ae_model.compile(optimizer='adam', loss=['mse', 'sparse_categorical_crossentropy'], loss_weights=[0.4, 0.6], metrics=[None, 'accuracy'])
#ae_model.fit(train_images, [train_images, train_labels], epochs=30, batch_size=128, validation_split=0.1)
# Out:
# Epoch 1/30
# /usr/local/lib/python3.11/dist-packages/keras/src/optimizers/base_optimizer.py:774: UserWarning: Gradients do not exist for variables ['LabelOutput/kernel', 'LabelOutput/bias'] when minimizing the loss. If using `model.compile()`, did you forget to provide a `loss` argument?
#   warnings.warn(
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - loss: 0.0790 - val_loss: 0.0282
# Epoch 2/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0275 - val_loss: 0.0246
# Epoch 3/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0247 - val_loss: 0.0234
# Epoch 4/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0233 - val_loss: 0.0225
# Epoch 5/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0226 - val_loss: 0.0217
# Epoch 6/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0219 - val_loss: 0.0212
# Epoch 7/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0213 - val_loss: 0.0206
# Epoch 8/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0205 - val_loss: 0.0200
# Epoch 9/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0199 - val_loss: 0.0196
# Epoch 10/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0195 - val_loss: 0.0193
# Epoch 11/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0191 - val_loss: 0.0189
# Epoch 12/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0187 - val_loss: 0.0186
# Epoch 13/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0183 - val_loss: 0.0184
# Epoch 14/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0180 - val_loss: 0.0183
# Epoch 15/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0178 - val_loss: 0.0181
# Epoch 16/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0176 - val_loss: 0.0180
# Epoch 17/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0172 - val_loss: 0.0179
# Epoch 18/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0173 - val_loss: 0.0177
# Epoch 19/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0170 - val_loss: 0.0176
# Epoch 20/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0170 - val_loss: 0.0176
# Epoch 21/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0168 - val_loss: 0.0174
# Epoch 22/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0167 - val_loss: 0.0175
# Epoch 23/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0164 - val_loss: 0.0175
# Epoch 24/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0163 - val_loss: 0.0173
# Epoch 25/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0163 - val_loss: 0.0173
# Epoch 26/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0162 - val_loss: 0.0173
# Epoch 27/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0161 - val_loss: 0.0173
# Epoch 28/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0161 - val_loss: 0.0172
# Epoch 29/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0159 - val_loss: 0.0172
# Epoch 30/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0159 - val_loss: 0.0171

# %%
# predykcja
imgs = train_images[:10]
pred = ae_model.predict(imgs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 575ms/step

# %%
# wizualizacja
plt.figure(figsize=(10,2))
for i in range(10):
    plt.subplot(2, 10, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(np.squeeze(imgs[i]), cmap=plt.cm.binary)
    plt.subplot(2, 10, i+1+10)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(np.squeeze(pred[i]), cmap=plt.cm.binary)
    #plt.xlabel(train_labels[image_ind])

# %%
# losowe wektory
ran = np.random.random((10,n))*2-1
ran
# Out:
# array([[ 5.81640570e-01,  5.61019544e-01, -3.95904655e-01,
#         -2.82098077e-01, -2.25821012e-01, -9.97691745e-01,
#         -2.80398392e-01, -3.49076231e-01, -5.58439513e-01],
#        [-7.16268848e-01,  2.43509769e-01,  1.76626345e-01,
#          8.09253590e-01, -6.00415127e-01, -6.01870901e-01,
#         -7.22211920e-01,  9.25748222e-01,  9.81335858e-01],
#        [-1.56854367e-01,  2.09742130e-01, -7.45706442e-01,
#          1.67389902e-01, -1.66357365e-01, -1.00239981e-01,
#          1.34086509e-01,  8.89822979e-01, -2.08917781e-01],
#        [ 7.38339975e-01,  5.87913942e-01,  4.54495948e-04,
#          2.60322257e-01, -3.60281443e-01,  9.24713354e-02,
#         -9.03120639e-01,  8.04812398e-01,  9.95813324e-01],
#        [ 8.67972882e-01, -4.91475922e-01,  9.48341364e-01,
#         -9.64696340e-01, -6.37809962e-01,  3.38117737e-01,
#         -4.58221945e-01,  8.55190412e-01, -8.28257046e-01],
#        [ 3.88362242e-02,  1.51020472e-01, -7.49756650e-01,
#          9.64585713e-01, -1.65390558e-01, -1.96600840e-01,
#         -4.13726028e-02, -2.58092666e-02, -4.90769827e-02],
#        [ 7.71897257e-01,  3.37450223e-01,  7.75313297e-01,
#         -7.28930676e-01,  4.30751799e-02,  2.92285402e-01,
#         -1.77714066e-01, -1.28068296e-01, -3.84711231e-01],
#        [ 2.16908799e-01, -4.28997286e-01, -5.65375682e-01,
#         -6.49676847e-01,  5.87477178e-01, -7.96071667e-01,
#         -6.37934845e-01,  2.28861666e-03, -1.30303423e-01],
#        [-6.61846374e-01,  8.60879166e-01,  5.43694197e-01,
#          5.76324610e-01, -9.47662118e-01, -8.29455893e-01,
#         -8.96883966e-01, -3.19223132e-01,  5.87246088e-01],
#        [-8.82647645e-01,  8.94488985e-01,  5.65318887e-01,
#         -6.06155867e-01, -8.84554429e-01,  9.90719788e-01,
#         -6.56245943e-01, -2.70825349e-02, -7.60619269e-01]])

# %%
ran_imgs = dec.predict(ran)
plt.figure(figsize=(10,2))
for i in range(10):
    plt.subplot(1, 10, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(np.squeeze(ran_imgs[i]), cmap=plt.cm.binary)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step

# %% [markdown]
# ## Wizualizacje przestrzeni ukrytej

# %%
latent = enc.predict(train_images)
# Out:
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step

# %%
#wizualizacja
plt.figure(figsize=(10,10))
for i in range(10):
    # Access the first element of latent (the latent vectors)
    latent_vectors = latent[0]
    plt.scatter(latent_vectors[np.where(train_labels==i), 0], latent_vectors[np.where(train_labels==i), 1], label=str(i))
plt.legend()
plt.show()

# %%
#wizualizacja wersja z klasyfikatorem
latent_vectors, _ = enc.predict(train_images)  # Unpack the output into latent_vectors and predicted_labels
plt.figure(figsize=(10,10))
for i in range(10):
    plt.scatter(latent_vectors[np.where(train_labels==i), 0], latent_vectors[np.where(train_labels==i), 1], label=str(i))
plt.legend()
plt.show()
# Out:
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming 'enc' is your encoder model, 'train_images' is your training data, and 'train_labels' are the true labels
latent_vectors, predicted_labels = enc.predict(train_images)  # Get both latent vectors and predicted labels

plt.figure(figsize=(10, 10))

# Iterate through each class (0-9)
for i in range(10):
    # Find indices of data points belonging to the current class, based on predicted labels
    indices = np.where(np.argmax(predicted_labels, axis=1) == i)

    # Plot these data points using their latent vectors for x and y coordinates
    plt.scatter(latent_vectors[indices, 0], latent_vectors[indices, 1], label=str(i))

plt.legend()
plt.title("Visualization of Latent Space with Classifier Predictions")
plt.xlabel("Latent Dimension 1")
plt.ylabel("Latent Dimension 2")
plt.show()
# Out:
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step

# %%
# wizualizacja, wersja z klasyfikatorem, funkcja linear zamiast tanh
import matplotlib.pyplot as plt
import numpy as np

latent_vectors, predicted_labels = enc.predict(train_images)  # Get both latent vectors and predicted labels

plt.figure(figsize=(10, 10))

for i in range(10):
    indices = np.where(np.argmax(predicted_labels, axis=1) == i)
    plt.scatter(latent_vectors[indices, 0], latent_vectors[indices, 1], label=str(i))

plt.legend()
plt.title("Visualization of Latent Space with Classifier Predictions (Linear Activation)")
plt.xlabel("Latent Dimension 1")
plt.ylabel("Latent Dimension 2")
plt.show()
# Out:
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step

# %% [markdown]
# ## Dodatkowe ćwiczenia
# - Dokonaj redukcji wymiarowości innymi algorytmami np. PCA, i zwizualizuj
# - Wygeneruj obrazy odtworzone z punktów leżących na okręgu o środku w (0,0), promień dobierz. Odpowienio dużo obrazów pokaże płynne przejścia pomiędzy klasami.
# - Zdefiniuj enkoder i dekoder używając warst odpowiednio konwolucyjnych i dekonwolucyjnych. Porównaj wyniki.

# %%
from tensorflow.keras.layers import Input, Dense, Flatten, Reshape, Conv2D, Conv2DTranspose
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt
import numpy as np
from sklearn.ensemble import IsolationForest

# Funkcja enkodera
def encoder_with_label(latent_dim, num_classes):
    input_img = Input(shape=(28, 28, 1))
    x = Conv2D(32, (3, 3), activation='relu', padding='same')(input_img)
    x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = Flatten()(x)
    latent = Dense(latent_dim, activation='relu')(x)
    label_output = Dense(num_classes, activation='softmax', name="LabelOutput")(latent)
    return Model(inputs=input_img, outputs=[latent, label_output], name="EncoderWithLabel")

# Funkcja dekodera
def decoder(latent_dim):
    latent_input = Input(shape=(latent_dim,))
    x = Dense(7 * 7 * 64, activation='relu')(latent_input)
    x = Reshape((7, 7, 64))(x)
    x = Conv2DTranspose(64, (3, 3), activation='relu', strides=(2, 2), padding='same')(x)  # Upsampling to 14x14
    x = Conv2DTranspose(32, (3, 3), activation='relu', strides=(2, 2), padding='same')(x)  # Upsampling to 28x28
    decoded = Conv2DTranspose(1, (3, 3), activation='sigmoid', padding='same', name="ReconstructionOutput")(x)
    return Model(inputs=latent_input, outputs=decoded, name="Decoder")

# Ładowanie danych MNIST
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0
x_train = np.expand_dims(x_train, axis=-1)  # Dodanie kanału
x_test = np.expand_dims(x_test, axis=-1)

# Parametry
latent_dim = 16
num_classes = 10

# Tworzenie modeli
enc = encoder_with_label(latent_dim, num_classes)
dec = decoder(latent_dim)

# Połączenie modeli w pełny autoenkoder
input_img = Input(shape=(28, 28, 1))
latent, label_output = enc(input_img)
reconstructed = dec(latent)
autoencoder = Model(inputs=input_img, outputs=[reconstructed, label_output], name="AutoencoderWithLabel")

# Kompilacja modelu
autoencoder.compile(
    optimizer='adam',
    loss=['mse', 'sparse_categorical_crossentropy'],  # Rekonstrukcja + Klasyfikacja
    metrics=[None, 'accuracy']  # Rekonstrukcja bez metryki, klasyfikacja z accuracy
)

# 1. Generowanie niestandardowego obrazu (np. losowy szum)
anomaly_image = np.random.rand(28, 28, 1)  # Szum o wymiarach 28x28x1

# Dodanie go do zbioru treningowego
x_train_with_anomaly = np.concatenate([x_train, anomaly_image.reshape(1, 28, 28, 1)], axis=0)
y_train_with_anomaly = np.concatenate([y_train, np.array([10])], axis=0)  # Oznaczenie jako "klasa 10" (nieistniejąca)

# Trening modelu na danych z anomalią
history = autoencoder.fit(
    x_train_with_anomaly, [x_train_with_anomaly, y_train_with_anomaly],
    epochs=30,
    batch_size=128,
    validation_split=0.1
)


# 2. Wykorzystanie przestrzeni latentnej do wykrywania anomalii
latent_representations = enc.predict(x_train_with_anomaly)[0]  # Uzyskiwanie reprezentacji latentnej dla danych treningowych

# Trenowanie modelu Isolation Forest na przestrzeni latentnej
iso_forest = IsolationForest(contamination=0.05)  # Przyjmujemy, że 5% danych to anomalie
iso_forest.fit(latent_representations)

# Predykcja anomalii na zbiorze testowym
latent_test = enc.predict(x_test)[0]  # Uzyskiwanie reprezentacji latentnej dla danych testowych
predicted_anomalies = iso_forest.predict(latent_test)  # -1 oznacza anomalię, 1 normalny

# Wizualizacja wyników detekcji anomalii w postaci wykresu:
anomaly_count = np.sum(predicted_anomalies == -1)  # Liczba anomalii
normal_count = np.sum(predicted_anomalies == 1)    # Liczba normalnych obrazów

# Wykres rozkładu detekcji anomalii w przestrzeni latentnej
plt.figure(figsize=(10, 8))

# Kolorowanie wyników: anomalie - czerwony, normalne - niebieski
plt.scatter(latent_test[:, 0], latent_test[:, 1], c=predicted_anomalies, cmap='coolwarm', s=50)
plt.title('Wykrywanie anomalii w przestrzeni latentnej')
plt.xlabel('Latent dimension 1')
plt.ylabel('Latent dimension 2')
plt.colorbar(label='Predykcja: 1-normalny, -1-anomalie')
plt.show()

# Wizualizacja wyników detekcji anomalii w postaci wykresu słupkowego
labels = ['Normalne', 'Anomalie']
counts = [normal_count, anomaly_count]

plt.bar(labels, counts, color=['green', 'red'])
plt.title('Liczba normalnych obrazów i anomalii')
plt.ylabel('Liczba obrazów')
plt.show()
# Out:
# Epoch 1/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 14s 22ms/step - Decoder_loss: 0.0787 - EncoderWithLabel_accuracy: 0.8301 - EncoderWithLabel_loss: 0.5435 - loss: 0.6222 - val_Decoder_loss: 0.0372 - val_EncoderWithLabel_accuracy: 0.9777 - val_EncoderWithLabel_loss: nan - val_loss: nan
# Epoch 2/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - Decoder_loss: 0.0356 - EncoderWithLabel_accuracy: 0.9805 - EncoderWithLabel_loss: 0.0643 - loss: 0.0999 - val_Decoder_loss: 0.0318 - val_EncoderWithLabel_accuracy: 0.9832 - val_EncoderWithLabel_loss: nan - val_loss: nan
# Epoch 3/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - Decoder_loss: 0.0312 - EncoderWithLabel_accuracy: 0.9858 - EncoderWithLabel_loss: 0.0450 - loss: 0.0762 - val_Decoder_loss: 0.0293 - val_EncoderWithLabel_accuracy: 0.9857 - val_EncoderWithLabel_loss: nan - val_loss: nan
# Epoch 4/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - Decoder_loss: 0.0288 - EncoderWithLabel_accuracy: 0.9915 - EncoderWithLabel_loss: 0.0281 - loss: 0.0569 - val_Decoder_loss: 0.0283 - val_EncoderWithLabel_accuracy: 0.9868 - val_EncoderWithLabel_loss: nan - val_loss: nan
# Epoch 5/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - Decoder_loss: 0.0275 - EncoderWithLabel_accuracy: 0.9933 - EncoderWithLabel_loss: 0.0211 - loss: 0.0486 - val_Decoder_loss: 0.0265 - val_EncoderWithLabel_accuracy: 0.9855 - val_EncoderWithLabel_loss: nan - val_loss: nan
# Epoch 6/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - Decoder_loss: 0.0263 - EncoderWithLabel_accuracy: 0.9954 - EncoderWithLabel_loss: 0.0140 - loss: 0.0404 - val_Decoder_loss: 0.0270 - val_EncoderWithLabel_accuracy: 0.9838 - val_EncoderWithLabel_loss: nan - val_loss: nan
# Epoch 7/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - Decoder_loss: 0.0258 - EncoderWithLabel_accuracy: 0.9955 - EncoderWithLabel_loss: 0.0134 - loss: 0.0392 - val_Decoder_loss: 0.0251 - val_EncoderWithLabel_accuracy: 0.9870 - val_EncoderWithLabel_loss: nan - val_loss: nan
# Epoch 8/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - Decoder_loss: 0.0244 - EncoderWithLabel_accuracy: 0.9973 - EncoderWithLabel_loss: 0.0084 - loss: 0.0328 - val_Decoder_loss: 0.0247 - val_EncoderWithLabel_accuracy: 0.9860 - val_EncoderWithLabel_loss: nan - val_loss: nan
# Epoch 9/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - Decoder_loss: 0.0240 - EncoderWithLabel_accuracy: 0.9971 - EncoderWithLabel_loss: 0.0079 - loss: 0.0318 - val_Decoder_loss: 0.0243 - val_EncoderWithLabel_accuracy: 0.9857 - val_EncoderWithLabel_loss: nan - val_loss: nan
# Epoch 10/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - Decoder_loss: 0.0233 - EncoderWithLabel_accuracy: 0.9984 - EncoderWithLabel_loss: 0.0056 - loss: 0.0289 - val_Decoder_loss: 0.0235 - val_EncoderWithLabel_accuracy: 0.9862 - val_EncoderWithLabel_loss: nan - val_loss: nan
# Epoch 11/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - Decoder_loss: 0.0230 - EncoderWithLabel_accuracy: 0.9978 - EncoderWithLabel_loss: 0.0067 - loss: 0.0297 - val_Decoder_loss: 0.0234 - val_EncoderWithLabel_accuracy: 0.9872 - val_EncoderWithLabel_loss: nan - val_loss: nan
# Epoch 12/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - Decoder_loss: 0.0226 - EncoderWithLabel_accuracy: 0.9988 - EncoderWithLabel_loss: 0.0042 - loss: 0.0268 - val_Decoder_loss: 0.0235 - val_EncoderWithLabel_accuracy: 0.9867 - val_EncoderWithLabel_loss: nan - val_loss: nan
# Epoch 13/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - Decoder_loss: 0.0228 - EncoderWithLabel_accuracy: 0.9983 - EncoderWithLabel_loss: 0.0056 - loss: 0.0283 - val_Decoder_loss: 0.0217 - val_EncoderWithLabel_accuracy: 0.9867 - val_EncoderWithLabel_loss: nan - val_loss: nan
# Epoch 14/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - Decoder_loss: 0.0215 - EncoderWithLabel_accuracy: 0.9991 - EncoderWithLabel_loss: 0.0032 - loss: 0.0247 - val_Decoder_loss: 0.0217 - val_EncoderWithLabel_accuracy: 0.9857 - val_EncoderWithLabel_loss: nan - val_loss: nan
# Epoch 15/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - Decoder_loss: 0.0213 - EncoderWithLabel_accuracy: 0.9988 - EncoderWithLabel_loss: 0.0034 - loss: 0.0247 - val_Decoder_loss: 0.0225 - val_EncoderWithLabel_accuracy: 0.9858 - val_EncoderWithLabel_loss: nan - val_loss: nan
# Epoch 16/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - Decoder_loss: 0.0212 - EncoderWithLabel_accuracy: 0.9987 - EncoderWithLabel_loss: 0.0033 - loss: 0.0245 - val_Decoder_loss: 0.0213 - val_EncoderWithLabel_accuracy: 0.9875 - val_EncoderWithLabel_loss: nan - val_loss: nan
# Epoch 17/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - Decoder_loss: 0.0208 - EncoderWithLabel_accuracy: 0.9987 - EncoderWithLabel_loss: 0.0034 - loss: 0.0242 - val_Decoder_loss: 0.0208 - val_EncoderWithLabel_accuracy: 0.9867 - val_EncoderWithLabel_loss: nan - val_loss: nan
# Epoch 18/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - Decoder_loss: 0.0207 - EncoderWithLabel_accuracy: 0.9985 - EncoderWithLabel_loss: 0.0043 - loss: 0.0249 - val_Decoder_loss: 0.0197 - val_EncoderWithLabel_accuracy: 0.9878 - val_EncoderWithLabel_loss: nan - val_loss: nan
# Epoch 19/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - Decoder_loss: 0.0195 - EncoderWithLabel_accuracy: 0.9995 - EncoderWithLabel_loss: 0.0016 - loss: 0.0211 - val_Decoder_loss: 0.0215 - val_EncoderWithLabel_accuracy: 0.9868 - val_EncoderWithLabel_loss: nan - val_loss: nan
# Epoch 20/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - Decoder_loss: 0.0205 - EncoderWithLabel_accuracy: 0.9983 - EncoderWithLabel_loss: 0.0049 - loss: 0.0254 - val_Decoder_loss: 0.0200 - val_EncoderWithLabel_accuracy: 0.9880 - val_EncoderWithLabel_loss: nan - val_loss: nan
# Epoch 21/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - Decoder_loss: 0.0196 - EncoderWithLabel_accuracy: 0.9993 - EncoderWithLabel_loss: 0.0023 - loss: 0.0219 - val_Decoder_loss: 0.0206 - val_EncoderWithLabel_accuracy: 0.9878 - val_EncoderWithLabel_loss: nan - val_loss: nan
# Epoch 22/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - Decoder_loss: 0.0200 - EncoderWithLabel_accuracy: 0.9983 - EncoderWithLabel_loss: 0.0044 - loss: 0.0244 - val_Decoder_loss: 0.0196 - val_EncoderWithLabel_accuracy: 0.9877 - val_EncoderWithLabel_loss: nan - val_loss: nan
# Epoch 23/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - Decoder_loss: 0.0190 - EncoderWithLabel_accuracy: 0.9996 - EncoderWithLabel_loss: 0.0015 - loss: 0.0205 - val_Decoder_loss: 0.0189 - val_EncoderWithLabel_accuracy: 0.9887 - val_EncoderWithLabel_loss: nan - val_loss: nan
# Epoch 24/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - Decoder_loss: 0.0187 - EncoderWithLabel_accuracy: 0.9994 - EncoderWithLabel_loss: 0.0020 - loss: 0.0206 - val_Decoder_loss: 0.0191 - val_EncoderWithLabel_accuracy: 0.9872 - val_EncoderWithLabel_loss: nan - val_loss: nan
# Epoch 25/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - Decoder_loss: 0.0190 - EncoderWithLabel_accuracy: 0.9989 - EncoderWithLabel_loss: 0.0030 - loss: 0.0220 - val_Decoder_loss: 0.0198 - val_EncoderWithLabel_accuracy: 0.9862 - val_EncoderWithLabel_loss: nan - val_loss: nan
# Epoch 26/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - Decoder_loss: 0.0190 - EncoderWithLabel_accuracy: 0.9991 - EncoderWithLabel_loss: 0.0032 - loss: 0.0222 - val_Decoder_loss: 0.0196 - val_EncoderWithLabel_accuracy: 0.9873 - val_EncoderWithLabel_loss: nan - val_loss: nan
# Epoch 27/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - Decoder_loss: 0.0187 - EncoderWithLabel_accuracy: 0.9995 - EncoderWithLabel_loss: 0.0020 - loss: 0.0206 - val_Decoder_loss: 0.0184 - val_EncoderWithLabel_accuracy: 0.9900 - val_EncoderWithLabel_loss: nan - val_loss: nan
# Epoch 28/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - Decoder_loss: 0.0176 - EncoderWithLabel_accuracy: 0.9998 - EncoderWithLabel_loss: 6.6080e-04 - loss: 0.0182 - val_Decoder_loss: 0.0195 - val_EncoderWithLabel_accuracy: 0.9863 - val_EncoderWithLabel_loss: nan - val_loss: nan
# Epoch 29/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - Decoder_loss: 0.0186 - EncoderWithLabel_accuracy: 0.9986 - EncoderWithLabel_loss: 0.0036 - loss: 0.0222 - val_Decoder_loss: 0.0186 - val_EncoderWithLabel_accuracy: 0.9865 - val_EncoderWithLabel_loss: nan - val_loss: nan
# Epoch 30/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - Decoder_loss: 0.0183 - EncoderWithLabel_accuracy: 0.9991 - EncoderWithLabel_loss: 0.0026 - loss: 0.0209 - val_Decoder_loss: 0.0178 - val_EncoderWithLabel_accuracy: 0.9905 - val_EncoderWithLabel_loss: nan - val_loss: nan
# 1876/1876 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
